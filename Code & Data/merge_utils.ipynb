# %% [markdown]
# # The code to get the utils data file

# %%
import pandas as pd
import geopandas as gpd

# %% [markdown]
# ### Loading the data

# %%
df_pop = pd.read_csv('data_raw\population.csv')

# %%
df_pop = (
    df_pop[df_pop['region_type'] == 'Neighbourhood']
    .groupby('region', as_index=False)['inhabitants'].sum()
)

# %%
df_light = (
    gpd.read_file('data_raw\lighting.geojson')
    .drop(['object_nummer',
            'mast_product',
            'straat',
            'armatuur_product',
            'lamp_product',
            'mast_hoogte'],
            axis=1)
)

# %%
df_work = (
    gpd.read_file('data_raw\work_locations.geojson')
    .drop(['identificatie',
            'validatiecode',
            'locatie',
            'woonplaats',
            'gemeente',
            'type_bedrijf'],
            axis=1)
    .rename(columns={'objectid': 'workplace_count'})
)

# %%
df_sport = (
    gpd.read_file('data_raw\sport_buildings.geojson')
    .drop(['IDENTIFICATIE',
            'NAAM',
            'STRAAT',
            'HUISNUMMER',
            'HUISLETTER',
            'HUISNUMMER_TOEVOEGING',
            'POSTCODE',
            'PLAATS',
            'SPORT_SOORT',
            'HOOFDBELEIDSVELD'],
            axis=1)
    .rename(columns={'OBJECTID': 'sport_building_count'})
)

# %%
df_regions = (
    gpd.read_file('data_raw\Buurten.geojson')
        .drop(['OBJECTID',
                'BUURTCODE',
                'WOONPLAATS',
                'GOUWCODE',
                'GEMEENTE',
                'GEMEENTECODE',
                'Shape__Area',
                'Shape__Length',
                'WOONPLAATSCODE',
                'OPPERVLAKTE'], axis=1)
        .rename(columns={'GOUW': 'WIJK'})
)

# %%
df_regions.head()
# Out:
#                 BUURT              WIJK  \
# 0         Kievitsloop  Breda noord-west
# 1         Princenhage        Breda west
# 2         Heusdenhout        Breda oost
# 3  Buitengebied Bavel             Bavel
# 4              Chassé     Breda centrum
#
#                                             geometry
# 0  POLYGON ((4.75141 51.61890, 4.75136 51.61882, ...
# 1  POLYGON ((4.74373 51.57291, 4.74363 51.57176, ...
# 2  POLYGON ((4.82923 51.59268, 4.82853 51.59194, ...
# 3  POLYGON ((4.87119 51.56827, 4.87135 51.56790, ...
# 4  POLYGON ((4.78630 51.58690, 4.78298 51.58366, ...

# %%
df_drugs = (
    pd.read_csv('data_raw\drugscords.csv')
        .drop(['totalScore',
               'reviewsCount',
               'street','city','state',
               'countryCode',
               'website',
               'phone',
               'categoryName',
               'url'],
                axis=1)
        
)

# %%
df_drugs = (
    gpd.GeoDataFrame(df_drugs,
                    geometry=gpd.points_from_xy(df_drugs['longitude'],
                                                df_drugs['latitude'],
                                                crs="EPSG:4326"))
        .drop(['latitude', 'longitude'], axis=1)
)

# %%
df_drugs.head()
# Out:
#                  title                  geometry
# 0            the Baron  POINT (4.78469 51.59150)
# 1                  Pax  POINT (4.76606 51.59057)
# 2  Coffeeshop Paradise  POINT (4.77811 51.58868)
# 3       Sky Coffeeshop  POINT (4.76005 51.58442)
# 4              The Cat  POINT (4.80523 51.58700)

# %% [markdown]
# ### Joining the data

# %%
df_join = df_regions.sjoin(df_light, how='inner').drop(['index_right'], axis=1)

# %%
df_join = df_join.dissolve(by=['WIJK', 'BUURT'], aggfunc='count', as_index=False)

# %%
df_join = df_join.rename(columns={'OBJECTID': 'light_count'})

# %%
df_join = df_join.sjoin(df_sport, how='left').drop('index_right', axis=1)

# %%
df_join = df_join.dissolve(by=['WIJK', 'BUURT', 'light_count'], aggfunc='count', as_index=False)

# %%
df_join = df_join.sjoin(df_work, how='left').drop('index_right', axis=1)

# %%
df_join = df_join.dissolve(by=['WIJK',
                                 'BUURT',
                                 'light_count', 
                                 'sport_building_count'],
                                 aggfunc='count',
                                 as_index=False)

# %%
df_join = df_join.sjoin(df_drugs, how='left')

# %%
df_join = df_join.dissolve(by=['WIJK',
                                'BUURT',
                                'light_count', 
                                'sport_building_count',
                                'workplace_count'],
                                aggfunc='count',
                                as_index=False)

# %%
df_join = df_join.merge(df_pop, left_on='BUURT', right_on='region', how='inner')

# %% [markdown]
# ### Renaming, dropping and changing the names of some columns

# %%
df_join = df_join.drop('region', axis=1)

# %%
df_join = df_join.rename(columns={'WIJK': 'regions', 'BUURT': 'neighborhood'})

# %%
centre = df_join[df_join['neighborhood'] == 'City']['geometry'].to_crs('EPSG:3310').centroid.iloc[0]

df_join = df_join.assign(
    light_per_1000 = lambda df: df['light_count'] / (df['inhabitants'] / 1000),
    sport_building_per_1000 = lambda df: df['sport_building_count'] / (df['inhabitants'] / 1000),
    area_sqkm = lambda df: df['geometry'].to_crs('EPSG:3310').area / 1_000_000,
    distance_from_centre_km = lambda df: df['geometry'].to_crs('EPSG:3310').centroid.distance(centre) / 1000
)

# %%
df_join = df_join.drop(['index_right', 'title'], axis=1)

# %%
df_join
# Out:
#              regions              neighborhood  light_count  \
# 0              Bavel                     Bavel         1253
# 1              Bavel        Buitengebied Bavel          308
# 2              Bavel           Nieuw Wolfslaar          515
# 3      Breda centrum                    Chassé          647
# 4      Breda centrum                      City          668
# 5      Breda centrum                Fellenoord          240
# 6      Breda centrum               Schorsmolen          329
# 7      Breda centrum                   Station          318
# 8      Breda centrum                Valkenberg          402
# 9        Breda noord                   Belcrum          637
# 10       Breda noord                  Biesdonk          710
# 11       Breda noord            Doornbos-Linie          963
# 12       Breda noord              Geeren-noord          455
# 13       Breda noord               Geeren-zuid          635
# 14       Breda noord                   Krogten          873
# 15       Breda noord               Waterdonken          483
# 16       Breda noord                 Wisselaar          678
# 17  Breda noord-west                      Emer          858
# 18  Breda noord-west                 Gageldonk          904
# 19  Breda noord-west                 Hagebeemd          170
# 20  Breda noord-west                Heksenwiel         1092
# 21  Breda noord-west                  Kesteren          857
# 22  Breda noord-west               Kievitsloop          826
# 23  Breda noord-west                   Kroeten          411
# 24  Breda noord-west                Muizenberg          675
# 25  Breda noord-west               Overkroeten          619
# 26        Breda oost               Brabantpark         1835
# 27        Breda oost               Heusdenhout          952
# 28        Breda oost                  Hoogeind          402
# 29        Breda oost            Moleneind-oost          195
# 30        Breda oost                 Sportpark          729
# 31        Breda oost                  Zandberg          586
# 32        Breda west                Effen-Rith          333
# 33        Breda west                 Haagpoort          290
# 34        Breda west                 Hazeldonk          256
# 35        Breda west                   Heilaar          429
# 36        Breda west                    Heuvel          961
# 37        Breda west                   Liesbos          471
# 38        Breda west               Princenhage         1729
# 39        Breda west                Steenakker          518
# 40        Breda west                  Tuinzigt          907
# 41        Breda west                Westerpark          782
# 42        Breda zuid                  Boeimeer          985
# 43        Breda zuid                Ruitersbos          776
# 44   Breda zuid-oost                Blauwe Kei          595
# 45   Breda zuid-oost                  Ginneken          725
# 46   Breda zuid-oost                   Mastbos          314
# 47   Breda zuid-oost                 Overakker          501
# 48   Breda zuid-oost                   Ypelaar          856
# 49       Prinsenbeek  Buitengebied Prinsenbeek          225
# 50       Prinsenbeek               Prinsenbeek         2368
# 51        Teteringen   Buitengebied Teteringen           81
# 52        Teteringen                Teteringen         2114
# 53        Teteringen               Vuchtpolder           44
# 54         Ulvenhout    Buitengebied Ulvenhout          143
# 55         Ulvenhout                 Ulvenhout         1098
#
#     sport_building_count  workplace_count  \
# 0                      2                2
# 1                      6                1
# 2                      0                0
# 3                      0                3
# 4                      0                3
# 5                      0                2
# 6                      0                1
# 7                      0                3
# 8                      0                3
# 9                      0                4
# 10                     3                2
# 11                     2                8
# 12                     0                0
# 13                     0                3
# 14                    13                5
# 15                     0                1
# 16                     1                0
# 17                     0                8
# 18                     5                2
# 19                     3                1
# 20                     5                1
# 21                     0                2
# 22                     2                3
# 23                     1                0
# 24                     6                2
# 25                     0                0
# 26                    13                9
# 27                     0                7
# 28                     0                4
# 29                     1                3
# 30                     0                3
# 31                     0                4
# 32                     0                0
# 33                     0                1
# 34                     0                1
# 35                     0                5
# 36                     2                2
# 37                     0                1
# 38                     4               10
# 39                     4                5
# 40                     4                6
# 41                     0                4
# 42                     7                6
# 43                    10                4
# 44                     6                5
# 45                     0                4
# 46                     6                1
# 47                     6                3
# 48                     2                4
# 49                     9                1
# 50                     9                4
# 51                     0                0
# 52                     6               10
# 53                     0                0
# 54                     0                1
# 55                     9                2
#
#                                              geometry  inhabitants  \
# 0   POLYGON ((4.83844 51.56120, 4.83911 51.56024, ...         5445
# 1   POLYGON ((4.87112 51.56696, 4.87096 51.56694, ...          570
# 2   POLYGON ((4.81440 51.55980, 4.81426 51.55978, ...         2365
# 3   POLYGON ((4.78176 51.58262, 4.78164 51.58253, ...         3365
# 4   POLYGON ((4.78086 51.58674, 4.78031 51.58705, ...         2575
# 5   POLYGON ((4.77310 51.58228, 4.77310 51.58229, ...         1565
# 6   POLYGON ((4.77039 51.58832, 4.77033 51.58828, ...         3450
# 7   POLYGON ((4.79096 51.59455, 4.79091 51.59450, ...         2310
# 8   POLYGON ((4.78866 51.59307, 4.78870 51.59305, ...         2005
# 9   POLYGON ((4.77500 51.59479, 4.77479 51.59477, ...         4005
# 10  POLYGON ((4.79155 51.60788, 4.79154 51.60786, ...         4895
# 11  POLYGON ((4.78781 51.59555, 4.78469 51.59540, ...         4435
# 12  POLYGON ((4.79155 51.60815, 4.79102 51.60908, ...         2695
# 13  POLYGON ((4.79376 51.60212, 4.79344 51.60211, ...         3720
# 14  POLYGON ((4.77710 51.60862, 4.77708 51.60862, ...          190
# 15  POLYGON ((4.80213 51.60987, 4.80215 51.60992, ...         1290
# 16  POLYGON ((4.78138 51.60997, 4.78124 51.60999, ...         4230
# 17  POLYGON ((4.76395 51.59976, 4.76394 51.59972, ...           75
# 18  POLYGON ((4.74723 51.60475, 4.74721 51.60459, ...         4620
# 19  POLYGON ((4.72587 51.62174, 4.72558 51.62189, ...          215
# 20  POLYGON ((4.75567 51.62527, 4.75605 51.62527, ...         4370
# 21  POLYGON ((4.72886 51.60751, 4.72885 51.60749, ...         3750
# 22  POLYGON ((4.75124 51.61792, 4.75127 51.61783, ...         4145
# 23  POLYGON ((4.73541 51.62632, 4.73541 51.62632, ...         2270
# 24  POLYGON ((4.73016 51.61309, 4.72970 51.61321, ...         2860
# 25  POLYGON ((4.73728 51.62243, 4.73720 51.62247, ...         3125
# 26  POLYGON ((4.80859 51.58186, 4.80849 51.58185, ...        10560
# 27  POLYGON ((4.82386 51.58307, 4.82373 51.58222, ...         5160
# 28  POLYGON ((4.84392 51.58542, 4.84398 51.58537, ...           45
# 29  POLYGON ((4.83020 51.59360, 4.83008 51.59350, ...           60
# 30  POLYGON ((4.79793 51.57768, 4.79760 51.57760, ...         3435
# 31  POLYGON ((4.78902 51.57601, 4.78881 51.57593, ...         5135
# 32  POLYGON ((4.73983 51.54764, 4.73993 51.54694, ...          875
# 33  POLYGON ((4.76512 51.58134, 4.76508 51.58128, ...         2165
# 34  POLYGON ((4.74617 51.48935, 4.74566 51.48918, ...           50
# 35  POLYGON ((4.74083 51.59188, 4.74076 51.59181, ...          570
# 36  POLYGON ((4.75968 51.57363, 4.75965 51.57361, ...         7490
# 37  POLYGON ((4.72608 51.57771, 4.72616 51.57754, ...          760
# 38  POLYGON ((4.74468 51.56884, 4.74505 51.56822, ...         8845
# 39  POLYGON ((4.75570 51.59313, 4.75587 51.59301, ...          480
# 40  POLYGON ((4.76499 51.59009, 4.76491 51.59005, ...         7650
# 41  POLYGON ((4.75012 51.58428, 4.75043 51.58376, ...         3430
# 42  POLYGON ((4.77694 51.57834, 4.77661 51.57815, ...         5790
# 43  POLYGON ((4.77731 51.56807, 4.77728 51.56790, ...         2485
# 44  POLYGON ((4.79778 51.57249, 4.79727 51.57219, ...         3835
# 45  POLYGON ((4.79333 51.55835, 4.79433 51.55829, ...         5440
# 46  POLYGON ((4.78936 51.55245, 4.78933 51.55241, ...          780
# 47  POLYGON ((4.80779 51.56108, 4.80790 51.56002, ...         3295
# 48  POLYGON ((4.80870 51.56584, 4.80732 51.56587, ...         5955
# 49  POLYGON ((4.70830 51.60830, 4.70830 51.60829, ...          900
# 50  POLYGON ((4.73009 51.59797, 4.73045 51.59779, ...        11350
# 51  POLYGON ((4.84096 51.61332, 4.84093 51.61328, ...          165
# 52  POLYGON ((4.82511 51.62070, 4.82513 51.62070, ...         8285
# 53  POLYGON ((4.81772 51.61847, 4.81655 51.61869, ...          105
# 54  POLYGON ((4.79965 51.53683, 4.80014 51.53660, ...          295
# 55  POLYGON ((4.81367 51.54985, 4.81435 51.54839, ...         4740
#
#     light_per_1000  sport_building_per_1000  area_sqkm  \
# 0       230.119376                 0.367309   1.750374
# 1       540.350877                10.526316   8.559273
# 2       217.758985                 0.000000   1.027985
# 3       192.273403                 0.000000   0.408947
# 4       259.417476                 0.000000   0.435064
# 5       153.354633                 0.000000   0.277823
# 6        95.362319                 0.000000   0.276399
# 7       137.662338                 0.000000   0.291627
# 8       200.498753                 0.000000   0.414723
# 9       159.051186                 0.000000   0.532119
# 10      145.045965                 0.612870   0.789697
# 11      217.136415                 0.450958   1.283557
# 12      168.831169                 0.000000   0.488354
# 13      170.698925                 0.000000   0.748957
# 14     4594.736842                68.421053   4.004618
# 15      374.418605                 0.000000   0.205434
# 16      160.283688                 0.236407   0.780115
# 17    11440.000000                 0.000000   2.424951
# 18      195.670996                 1.082251   0.795858
# 19      790.697674                13.953488   9.166315
# 20      249.885584                 1.144165   0.934977
# 21      228.533333                 0.000000   0.767038
# 22      199.276236                 0.482509   0.867487
# 23      181.057269                 0.440529   0.440344
# 24      236.013986                 2.097902   0.904500
# 25      198.080000                 0.000000   0.463764
# 26      173.768939                 1.231061   2.264479
# 27      184.496124                 0.000000   1.523025
# 28     8933.333333                 0.000000   2.193591
# 29     3250.000000                16.666667   0.435414
# 30      212.227074                 0.000000   1.216867
# 31      114.118793                 0.000000   0.736004
# 32      380.571429                 0.000000   8.977619
# 33      133.949192                 0.000000   0.250617
# 34     5120.000000                 0.000000   3.118867
# 35      752.631579                 0.000000   1.593767
# 36      128.304406                 0.267023   1.036622
# 37      619.736842                 0.000000   6.022197
# 38      195.477671                 0.452233   2.636111
# 39     1079.166667                 8.333333   1.092441
# 40      118.562092                 0.522876   1.159033
# 41      227.988338                 0.000000   0.660707
# 42      170.120898                 1.208981   1.215987
# 43      312.273642                 4.024145   1.758054
# 44      155.149935                 1.564537   0.704260
# 45      133.272059                 0.000000   1.358979
# 46      402.564103                 7.692308  13.408703
# 47      152.048558                 1.820941   1.341492
# 48      143.744752                 0.335852   1.174145
# 49      250.000000                10.000000  13.512198
# 50      208.634361                 0.792952   3.600666
# 51      490.909091                 0.000000   2.358730
# 52      255.159928                 0.724200   3.351888
# 53      419.047619                 0.000000   5.729860
# 54      484.745763                 0.000000   3.483987
# 55      231.645570                 1.898734   1.737026
#
#     distance_from_centre_km
# 0                  4.594220
# 1                  5.384812
# 2                  3.831573
# 3                  0.566532
# 4                  0.000000
# 5                  0.648226
# 6                  0.584711
# 7                  0.692898
# 8                  0.594466
# 9                  0.935204
# 10                 1.909613
# 11                 1.758214
# 12                 2.756999
# 13                 2.323636
# 14                 2.876708
# 15                 2.969386
# 16                 2.656641
# 17                 2.105793
# 18                 2.924218
# 19                 5.275766
# 20                 4.241949
# 21                 4.118704
# 22                 3.266591
# 23                 4.830311
# 24                 4.578319
# 25                 4.790028
# 26                 1.937896
# 27                 3.031527
# 28                 4.199092
# 29                 3.680454
# 30                 1.459725
# 31                 1.351544
# 32                 5.495541
# 33                 1.260602
# 34                 9.245683
# 35                 3.134883
# 36                 2.298333
# 37                 5.142709
# 38                 3.159405
# 39                 2.741082
# 40                 1.335237
# 41                 2.154857
# 42                 1.435176
# 43                 2.541745
# 44                 2.066580
# 45                 2.697776
# 46                 4.754396
# 47                 3.232631
# 48                 2.906413
# 49                 6.984466
# 50                 4.425985
# 51                 4.782513
# 52                 3.825772
# 53                 4.047101
# 54                 5.042442
# 55                 4.691592

# %% [markdown]
# ### Saving the data to a GeoJSON file

# %%
df_join.to_file('data_raw\\utils.geojson', driver='GeoJSON')
