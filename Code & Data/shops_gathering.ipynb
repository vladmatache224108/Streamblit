# %%
import csv

# %%
shops = {
    '51.5846934, 4.776879': {
        'Algorithmic Perfumery',
        'Aktiesport',
        'America Today',
        'Bargello',
        'Blokker',
        'Boekenvoordeel',
        'C&A',
        'CallStars',
        'CASA',
        'Chasin’',
        'Claires',
        'Cotton Club',
        'Disini dameskleding',
        'Distrikt',
        'Diva Shoes',
        'Donna Li',
        'Esprit',
        'Eyewish',
        'Gerry Weber',
        '’t Ginneke Juwelier',
        'GSM Specialist',
        'H&M',
        'Handyman',
        'Hans Anders',
        'Hema',
        'Holland & Barrett',
        'JD Sports',
        'Jeans Centre',
        'KPN Winkel',
        'Kruidvat',
        'Linolux',
        'Lucardi',
        'McFlek',
        'Mertens Oogmode',
        'Miss Etam',
        'Name It',
        'Only',
        'Open32',
        'Pearle Opticiens',
        'Perry Sport',
        'Phone House',
        'Sacha',
        'Score',
        'Snipes',
        'SPAR city store',
        'SoLow',
        'SONS',
        'Søstrene Grene',
        'SNS Winkel',
        'Sven & Sophie',
        'T-Mobile',
        'Topshopz',
        'Van Uffelen',
        'Vero Moda',
        'Vodafone',
        'Ulla Popken',
        'Wam Denim',
        'WE',
        'Wibra',
        'Zeeman'
    },
    '51.5848002,4.7761683': {
        'Be-you-tiful',
        'Brandfield',
        'Cadeauwinkel WAAR',
        'Candles and Cards',
        'De Pindakaaswinkel',
        'Dstrezzed',
        'Hutspot',
        'Home Stock',
        'Jollywood',
        'Rituals',
        'Smaack Traiteur & Delicatessen',
        'Superdry',
        'Velvet',
        'Urban Bozz',
    },
    '51.5862523, 4.7744702': {
            'Amac',
            'Aspact',
            'Clarks',
            'Costes',
            'Didi',
            'Douglas',
            'Expresso',
            'G-Star RAW',
            'Hunkemöller',
            'ICI Paris XL',
            'Jack & Jones',
            'Just Brands',
            'Kruidvat',
            'Levi’s',
            'Manfield',
            'Nelson',
            'Paprika',
            'Promiss',
            'Scotch & Soda',
            'Sneakers',
            'Steps',
            'Swarovski',
            'Van Arendonk',
            'VanHaren',
        }
    '51.5866081,4.7735489': {
        "Claudia Sträter",
        "Ecco",
        "Foot Locker",
        "LaDress",
        "L’Occitane",
        "Nespresso",
        "NIKKIE",
        "Purdey",
        "Tommy Hilfiger",
        "Sunglass Hut",
    }

    
    
    
}
# Out:
#   File "C:\Users\thijn\AppData\Local\Temp\ipykernel_14304\2710732682.py", line 81
#     '51.5862523, 4.7744702': {
#     ^
# SyntaxError: invalid syntax

# %%
{
    '51.5866081,4.7735489': {
        "Claudia Sträter",
        "Ecco",
        "Foot Locker",
        "LaDress",
        "L’Occitane",
        "Nespresso",
        "NIKKIE",
        "Purdey",
        "Tommy Hilfiger",
        "Sunglass Hut",
    }
}

# %%
with open('shops.csv', mode='w', newline='') as csv_file:
    fieldnames = ['coordinates', 'names']
    writer = csv.DictWriter(csv_file, fieldnames=fieldnames)
    writer.writeheader()

    for coordinates, names in shops.items():
        for name in names:
            writer.writerow({'coordinates': coordinates, 'names': name})
